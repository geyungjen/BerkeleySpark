# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create a matrix x

# %%
mu = [0,0]
sigma = [[0.6,0.2],[0.2,0.2]]
n = 1000
x = np.random.multivariate_normal(mu, sigma, n).T

# %% [markdown]
# ### Get its covariance matrix

# %%
A=np.cov(x)

# %%
x
# Out:
# array([[ 0.77391174, -1.33847946,  0.44494589, ..., -0.15015718,
#         -0.47035637,  0.08868405],
#        [ 0.57521557, -0.2566267 ,  0.01770044, ...,  0.47490328,
#         -0.94256696,  0.27099385]])

# %%
A
# Out:
# array([[0.57270643, 0.19248315],
#        [0.19248315, 0.19431355]])

# %% [markdown]
# ### Get eigenvalues and eigenvectors from covariance matrix

# %%
eigenvals, eigenvecs = np.linalg.eig(A)

# %%
eigenvals
# Out:
# array([0.65340822, 0.11361176])

# %%
eigenvecs
# Out:
# array([[ 0.92222334, -0.38665762],
#        [ 0.38665762,  0.92222334]])

# %% [markdown]
# ### Eigenvector corresponding to the largest eigenvalue shold be the 1st to be plotted as new axle system. Plot line to reflect gradiance of eigenvecs (0,0.92222334) and (0, 0.38665762) as first eigen axles, because 1st eigenval is abs(0.65340822) > 2nd one, abs(-0.38665762); Plot line to reflect (0, -0.38665762), (0.92222334) as second eigen axles

# %%
plt.scatter(x[0,:], x[1,:], alpha=0.2)
plt.plot([0, 3*eigenvals[0]*eigenvecs[0][0]], [0, 3*e[0]*v[1][0]], 'r-', lw=2) #larger eigenvecs
plt.plot([0, 3*eigenvals[1]*eigenvecs[0][1]], [0, 3*e[1]*v[1][1]], 'r-', lw=2) #smaller eigenvecs
plt.plot([0, -3*eigenvals[0]*eigenvecs[0][0]], [0, -3*e[0]*v[1][0]], 'r-', lw=2) #larger eigenvecs
plt.plot([0, -3*eigenvals[1]*eigenvecs[0][1]], [0, -3*e[1]*v[1][1]], 'r-', lw=2) #smaller eigenvecs
